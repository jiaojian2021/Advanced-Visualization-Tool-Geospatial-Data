# %% [markdown]
# # Python Seaborn Plotting Functions

# %% [markdown]
# The Seaborn library provides a range of plotting functions that makes the visualization and analysis of data easier. You’ll cover some of the crucial plots in this tutorial.

# %% [markdown]
# # Import data and Data Wrangling

# %%
# importing the required library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
 
# read a csv file
df = pd.read_csv('Tips.csv')
 
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.shape
# Out:
# (244, 7)

# %%
df.replace("?", np.nan, inplace = True)
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Barplot

# %% [markdown]
# A bar plot gives an estimate of the central tendency for a numeric variable with the height of each rectangle. It provides some indication of the uncertainty around that estimate using error bars. To build this plot, you usually choose a categorical column on the x-axis and a numerical column on the y-axis.

# %%
sns.barplot(x='sex',y='tip',data = df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x='day',y='tip',data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.barplot(x='time', y='tip',data = df, color = 'yellow')
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.barplot(df['size'],df['tip'],palette= 'flare')
# Out:
# /Users/jiaojian/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# # Countplot

# %% [markdown]
# The countplot() function in the Python Seaborn library returns the count of total values for each category using bars.

# %%
sns.countplot(x='size', data=df, palette="Set1")
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %%
sns.countplot(y='size', hue = 'day', data = df, palette = 'Set1')
# Out:
# <AxesSubplot:xlabel='count', ylabel='size'>

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# The Seaborn library supports the distplot() function that creates the distribution of any continuous data. In the below example, you must plot the distribution of tip per bill.

# %%
sns.distplot(df['tip'], bins = 10, color = 'g')
# Out:
# /Users/jiaojian/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='tip', ylabel='Density'>

# %% [markdown]
# # Heatmap

# %% [markdown]
# Heatmaps in the Seaborn library lets you visualize matrix-like data. The values of the variables are contained in a matrix and are represented as colors. Below is an example of the heatmap where you are finding the correlation between each variable in the df dataset.

# %%
sns.heatmap(df.corr(), cbar=True, linewidths = 0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Scatterplot

# %% [markdown]
# The Seaborn scatterplot() function helps you create plots that can draw relationships between two continuous variables.

# %%
sns.scatterplot(x='total_bill',y='tip',data=df, hue="smoker",palette = 'Set2')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %% [markdown]
# A boxplot, also known as a box and whisker plot, depicts the distribution of quantitative data. The box represents the quartiles of the dataset. The whiskers show the rest of the distribution, except for the outlier points.

# %%
sns.boxplot(x = 'time', y = 'tip', data = df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %% [markdown]
# # Pairplot

# %% [markdown]
# The Python Seaborn library lets you visualize data using pair plots that produce a matrix of relationships between each variable in the dataset.
#
# In the below plot, all the plots are histograms that represent the distribution of each feature.

# %%
sns.pairplot(df)

# %% [markdown]
# You can convert the diagonal visuals to KDE plots and the rest to scatter plots using the hue parameter. This makes the pairplot easier to classify each type of one parameter.

# %%
sns.pairplot(df, hue='smoker', palette = 'Set1')

# %% [markdown]
# #  Regression Plot

# %% [markdown]
# The regplot() and lmplot() function in the Seaborn library draws a linear and higher-order-polynomial relationship as determined through regression for the continuous variables.
#
# The plot below shows the relationship between total bill and tip per bill.

# %%
sns.regplot(x ='total_bill', y ='tip', data = df, order=1, ci=None)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.regplot(x ='total_bill', y ='tip', data = df, order=3, ci=None)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x ='total_bill', y ='tip',fit_reg = True, hue = 'sex', data = df, order=3, ci=None)

# %%
sns.lmplot(x ='total_bill', y ='tip',fit_reg = True, col = 'sex', data = df, order=3, ci=None)
